# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# # Connected?

# %%
n = 500
connected = np.zeros(100)
i = 0
probs = np.linspace(0, 5*np.log(n)/n, 100)
for p in probs:
    g = nx.fast_gnp_random_graph(n, p)
    if len(sorted(nx.connected_components(g), key = len, reverse=True)) == 1:
        connected[i] = 1
    i = i + 1

# %%
fig, ax = plt.subplots(1,1)
p=ax.plot(probs, connected)
plt.xlabel('p')
plt.ylabel('is connected? (0/1)')

# %% [markdown]
# # Giant Component

# %%
n=5000
g_comp = np.zeros(100)
i = 0
probs = np.linspace(0, 5*1/float(n), 100)
for p in probs:
    g = nx.fast_gnp_random_graph(n, p)
    g_comp[i] = len(sorted(nx.connected_components(g), key = len, reverse=True)[0])
    i = i + 1

# %%
plt.plot(probs, g_comp)

plt.xlabel('p')
plt.ylabel('Size of largest component')

# %%
nx.draw_circular(g)
# Out:
# /usr/lib64/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
