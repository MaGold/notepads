# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
sns.set(color_codes=True)
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 23 days

# %%
n=100000

blue_train = 0.3*np.random.randn(n,2) - np.array([2,0])
plt.plot(blue_train[:,0], blue_train[:,1], 'o', color='b')

orange_train = 0.5*np.random.randn(n,2) + np.array([4,5])
plt.plot(orange_train[:,0], orange_train[:,1], 'o', color='orange')

red_train = 0.8*np.random.randn(n,2) + np.array([3,2])
plt.plot(red_train[:,0], red_train[:,1], 'o', color='red')

plt.xlim([-10,10])
plt.ylim([-10,10])
# Out:
# (-10, 10)

# %%
x_train = np.vstack((blue_train, orange_train, red_train))

# %%
x_train.shape
# Out:
# (300000, 2)

# %%
plt.plot(x_train[:,0], x_train[:,1], '.', color='black')
plt.xlim([-10,10])
plt.ylim([-10,10])
# Out:
# (-10, 10)

# %%
y_train = np.hstack((np.zeros(n), np.ones(n), 2*np.ones(n))).T
y_train.shape
# Out:
# (300000,)

# %%
print x_train.shape, y_train.shape
# Out:
# (300000, 2) (300000,)

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(x_train, y_train)

print(clf.predict([[-0.8, -1]]))
# Out:
# [ 0.]

# %%
x_test = 20*np.random.rand(100000,2)-10
y_test = clf.predict(x_test)

# %%
colors = np.array(["blue", "orange", "red"])
#for x in x_test:
    #cls = int(clf.predict([x])[0])
    #plt.plot(x[0], x[1], '.', color=colors[cls])
    
sizes = 4*(np.ones(len(x_test)))
plt.scatter(x_test[:,0], x_test[:,1], c=colors[y_test.astype(int)], s=sizes)

plt.plot(orange_train[:,0],orange_train[:,1], marker='o',  markersize=10, color='orange', alpha=0.25)
plt.plot(blue_train[:,0],blue_train[:,1], marker='o', markersize=10, color='blue', alpha=0.25)
plt.plot(red_train[:,0],red_train[:,1], marker='o', markersize=10, color='red', alpha=0.25)


plt.xlim([-10,10])
plt.ylim([-10,10])
# Out:
# (-10, 10)
